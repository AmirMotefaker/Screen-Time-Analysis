# %% [markdown]
# <a href="https://www.kaggle.com/code/amirmotefaker/screentime-application-analysis?scriptVersionId=146422141" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Screen Time Applicayion
#
# - Screen Time Analysis lets you know how much time you spend on what kind of applications and websites using your device. And screen time analysis gives a visual report of the same.
